# %% [markdown]
# ## 1. Préparation de l'environnement et des données ESS pour les tiers lieux en France
#
#  La base France tiers lieux est créé et recense tous les tiers lieux en france. Je vais sortir seulement ceux qui sont autour du numérique

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Utilisateur\\OneDrive\\Documents\\centrale Lille + sc po\\Projet SOGA\\ess-numerique-database\\data\\raw\\bdftl-2023-04-activites.csv', sep=';', low_memory=False)

# %%
cols_numerique = [
    'TYPE_ACT_NUMER', 'PROD_NUMER', 'THEME_FORM_NUMER', 
    'THEME_FORM_INFOR', 'THEME_FORM_PROGRAM', 'OFFRE_NUM_FABR', 
    'OFFRE_NUM_INCLU', 'OFFRE_NUM_MENUM', 'EQPT_NUM'
]

# %%
df_numerique = df[df[cols_numerique].all(axis=1) == True]

# %%
df_final = df_numerique[['NOM', 'Insee', 'TYPE_ACT']]

# %%
df_final
# Out:
#                                                     NOM  Insee  \
# 6                                                    2D  29151
# 68                       Anonymal - La Maison Numérique  13001
# 99          Atelier Made in iKi - FabLab Bresse du Jura  39160
# 128                                      Axelle Benaich  13055
# 158                            Bordeaux Ecole Numerique  33039
# 249                                              Cocoba  64260
# 266          Consortium TIX (Tiers-lieu numérique CASF)  67046
# 303                                              Cycle²  41255
# 322   Ec(H)o Village ELISA, en Transition, Durable e...  97418
# 353                                Escale &amp; CO (L')  24322
# 354                                           Espac'Num  49023
# 445                                             Fabrico  26362
# 492              GFIIP - GuyaFab Innovation In Progress  97304
# 501                                         Gullivigne-  44043
# ...

# %%
df_final.to_excel('C:\\Users\\Utilisateur\\OneDrive\\Documents\\centrale Lille + sc po\\Projet SOGA\\ess-numerique-database\\data\\processed\\ftl_numerique.xlsx', index=False)
# Out:
# <ipython-input-17-00e9ae84c333>:1: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   df_final.to_excel('C:\\Users\\Utilisateur\\OneDrive\\Documents\\centrale Lille + sc po\\Projet SOGA\\ess-numerique-database\\data\\processed\\ftl_numerique.xlsx', index=False)
